# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

df = pd.read_excel('prphet_predcitions.xlsx')
json_data = df.to_json(orient='records')

parsed_json = json.loads(json_data)
result = {item.pop(df.columns[0]): item for item in parsed_json}

print(json.dumps(result, indent=4))
# Out:
# {
#     "120011556": {
#         "WEEK - 1": 178.43,
#         "WEEK - 2": 147.5,
#         "WEEK - 3": 93.14,
#         "WEEK - 4": 86.56,
#         "WEEK - 5": 163.79,
#         "WEEK - 6": 275.0,
#         "WEEK - 7": 327.83,
#         "WEEK - 8": 280.18
#     },
#     "120010342": {
#         "WEEK - 1": 558.95,
#         "WEEK - 2": 743.03,
#         "WEEK - 3": 891.71,
#         "WEEK - 4": 871.23,
#         "WEEK - 5": 744.89,
#         "WEEK - 6": 669.65,
#         "WEEK - 7": 714.28,
#         "WEEK - 8": 816.27
#     },
#     "120009814": {
#         "WEEK - 1": 299.49,
#         "WEEK - 2": 475.92,
#         "WEEK - 3": 636.29,
#         "WEEK - 4": 649.94,
#         "WEEK - 5": 530.89,
#         "WEEK - 6": 408.54,
#         "WEEK - 7": 387.17,
#         "WEEK - 8": 452.66
#     },
#     "120009816": {
#         "WEEK - 1": 702.7,
#         "WEEK - 2": 478.86,
#         "WEEK - 3": 390.42,
#         "WEEK - 4": 526.27,
#         "WEEK - 5": 816.31,
#         "WEEK - 6": 1093.13,
#         "WEEK - 7": 1212.41,
#         "WEEK - 8": 1142.2
#     },
#     "120011782": {
#         "WEEK - 1": 2608.26,
#         "WEEK - 2": 2590.94,
#         "WEEK - 3": 2597.92,
#         "WEEK - 4": 2635.72,
#         "WEEK - 5": 2706.25,
#         "WEEK - 6": 2771.84,
#         "WEEK - 7": 2764.17,
#         "WEEK - 8": 2645.67
#     },
#     "120014486": {
#         "WEEK - 1": 2360.18,
#         "WEEK - 2": 2260.82,
#         "WEEK - 3": 2334.4,
#         "WEEK - 4": 2322.4,
#         "WEEK - 5": 2093.36,
#         "WEEK - 6": 1891.94,
#         "WEEK - 7": 2121.32,
#         "WEEK - 8": 2848.6
#     },
#     "120014488": {
#         "WEEK - 1": 2165.55,
#         "WEEK - 2": 2052.9,
#         "WEEK - 3": 2080.22,
#         "WEEK - 4": 2227.95,
#         "WEEK - 5": 2311.37,
#         "WEEK - 6": 2181.34,
#         "WEEK - 7": 1943.78,
#         "WEEK - 8": 1894.46
#     },
#     "120015996": {
#         "WEEK - 1": 2142.0,
#         "WEEK - 2": 2180.4,
#         "WEEK - 3": 2059.5,
#         "WEEK - 4": 1654.58,
#         "WEEK - 5": 1205.52,
#         "WEEK - 6": 1138.42,
#         "WEEK - 7": 1605.39,
#         "WEEK - 8": 2261.24
#     }
# }
